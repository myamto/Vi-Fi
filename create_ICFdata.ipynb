# %% [markdown]
# <a href="https://colab.research.google.com/github/myamto/Vi-Fi/blob/master/create_ICFdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
BSDE = ['b']

pre_url = 'http://www.icfcy-jpn.org/e-angel/icfdb/icfdb_all.cgi?IDv001=&IDn001=AND&keys1='
post_url = '&keys2=&keys3=&keys4=&keys5=&keys6=&print=1'


def icf(n):
  if (int(n/10)):
    return icf(int(n/9)) + str(n%9)
  return str(n%9)
  
write_list=[]
for head in BSDE:
  for N in [1, 3, 4, 5]:
    print(N)
    for i in range(9**N):
      num = icf(i).zfill(N)
      code = head + num
      url = pre_url + code + post_url

      html = urlopen(url)
      soup = BeautifulSoup(html, "html.parser")

      try:
        table = soup.findAll("table")[0]
        rows = table.findAll("td", {"width":"85%"})
        write_list.append([rows[0].get_text(), rows[1].get_text(), rows[3].get_text(), rows[4].get_text()])
        print('N=' + str(N) + ',' + code + ',' + rows[0].get_text())
      except:
        pass

with open('icf_database.csv', 'w') as f:
          writer = csv.writer(f)
          writer.writerows(write_list)
# Out:
# 1
# N=1,b1,  b1
# N=1,b2,  b2
# N=1,b3,  b3
# N=1,b4,  b4
# N=1,b5,  b5
# N=1,b6,  b6
# N=1,b7,  b7
# N=1,b8,  b8
# 3
# N=3,b110,  b110
# N=3,b114,  b114
# N=3,b117,  b117
# N=3,b122,  b122
# N=3,b126,  b126
# N=3,b130,  b130
# N=3,b134,  b134
# N=3,b140,  b140
# N=3,b144,  b144
# N=3,b147,  b147
# N=3,b152,  b152
# N=3,b156,  b156
# N=3,b160,  b160
# N=3,b164,  b164
# N=3,b167,  b167
# N=3,b172,  b172
# N=3,b176,  b176
# N=3,b180,  b180
# N=3,b210,  b210
# N=3,b215,  b215
# N=3,b220,  b220
# N=3,b230,  b230
# N=3,b235,  b235
# N=3,b240,  b240
# N=3,b250,  b250
# N=3,b255,  b255
# N=3,b260,  b260
# N=3,b265,  b265
# N=3,b270,  b270
# N=3,b280,  b280
# N=3,b310,  b310
# N=3,b320,  b320
# N=3,b330,  b330
# N=3,b340,  b340
# N=3,b410,  b410
# N=3,b415,  b415
# N=3,b420,  b420
# N=3,b430,  b430
# N=3,b435,  b435
# N=3,b440,  b440
# N=3,b445,  b445
# N=3,b450,  b450
# N=3,b455,  b455
# N=3,b460,  b460
# N=3,b510,  b510
# N=3,b515,  b515
# N=3,b520,  b520
# N=3,b525,  b525
# N=3,b530,  b530
# N=3,b535,  b535
# N=3,b540,  b540
# N=3,b545,  b545
# N=3,b550,  b550
# N=3,b555,  b555
# N=3,b610,  b610
# N=3,b620,  b620
# N=3,b630,  b630
# N=3,b640,  b640
# N=3,b650,  b650
# N=3,b660,  b660
# N=3,b670,  b670
# N=3,b710,  b710
# N=3,b715,  b715
# N=3,b720,  b720
# N=3,b730,  b730
# N=3,b735,  b735
# N=3,b740,  b740
# N=3,b750,  b750
# N=3,b755,  b755
# N=3,b760,  b760
# N=3,b765,  b765
# N=3,b770,  b770
# N=3,b780,  b780
# N=3,b810,  b810
# N=3,b820,  b820
# N=3,b830,  b830
# N=3,b840,  b840
# N=3,b850,  b850
# N=3,b860,  b860
# 4
# N=4,b1100,  b1100
# N=4,b1101,  b1101
# N=4,b1102,  b1102
# N=4,b1108,  b1108
# N=4,b1140,  b1140
# N=4,b1141,  b1141
# N=4,b1142,  b1142
# N=4,b1148,  b1148
# N=4,b1260,  b1260
# N=4,b1261,  b1261
# N=4,b1262,  b1262
# N=4,b1263,  b1263
# N=4,b1264,  b1264
# N=4,b1265,  b1265
# N=4,b1266,  b1266
# N=4,b1267,  b1267
# N=4,b1268,  b1268
# N=4,b1300,  b1300
# N=4,b1301,  b1301
# N=4,b1302,  b1302
# N=4,b1303,  b1303
# N=4,b1304,  b1304
# N=4,b1308,  b1308
# N=4,b1340,  b1340
# N=4,b1341,  b1341
# N=4,b1342,  b1342
# N=4,b1343,  b1343
# N=4,b1344,  b1344
# N=4,b1348,  b1348
# N=4,b1400,  b1400
# N=4,b1401,  b1401
# N=4,b1402,  b1402
# N=4,b1403,  b1403
# N=4,b1408,  b1408
# N=4,b1440,  b1440
# N=4,b1441,  b1441
# N=4,b1442,  b1442
# N=4,b1448,  b1448
# N=4,b1470,  b1470
# N=4,b1471,  b1471
# N=4,b1478,  b1478
# N=4,b1520,  b1520
# N=4,b1521,  b1521
# N=4,b1522,  b1522
# N=4,b1528,  b1528
# N=4,b1560,  b1560
# N=4,b1561,  b1561
# N=4,b1562,  b1562
# N=4,b1563,  b1563
# N=4,b1564,  b1564
# N=4,b1565,  b1565
# N=4,b1568,  b1568
# N=4,b1600,  b1600
# N=4,b1601,  b1601
# N=4,b1602,  b1602
# N=4,b1603,  b1603
# N=4,b1608,  b1608
# N=4,b1640,  b1640
# N=4,b1641,  b1641
# N=4,b1642,  b1642
# N=4,b1643,  b1643
# N=4,b1644,  b1644
# N=4,b1645,  b1645
# N=4,b1646,  b1646
# N=4,b1648,  b1648
# N=4,b1670,  b1670
# N=4,b1671,  b1671
# N=4,b1672,  b1672
# N=4,b1678,  b1678
# N=4,b1720,  b1720
# N=4,b1721,  b1721
# N=4,b1728,  b1728
# N=4,b1800,  b1800
# N=4,b1801,  b1801
# N=4,b1802,  b1802
# N=4,b1808,  b1808
# N=4,b2100,  b2100
# N=4,b2102,  b2102
# N=4,b2108,  b2108
# N=4,b2150,  b2150
# N=4,b2151,  b2151
# N=4,b2152,  b2152
# N=4,b2153,  b2153
# N=4,b2158,  b2158
# N=4,b2300,  b2300
# N=4,b2301,  b2301
# N=4,b2302,  b2302
# N=4,b2303,  b2303
# N=4,b2304,  b2304
# N=4,b2308,  b2308
# N=4,b2350,  b2350
# N=4,b2351,  b2351
# N=4,b2352,  b2352
# N=4,b2358,  b2358
# N=4,b2400,  b2400
# N=4,b2401,  b2401
# N=4,b2402,  b2402
# N=4,b2403,  b2403
# N=4,b2404,  b2404
# N=4,b2405,  b2405
# N=4,b2408,  b2408

# %%
from google.colab import files
files.download('icf_database.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d5cb1530bbf2> in <module>()
#       2 with open('icf_database.csv', 'w') as f:
#       3           writer = csv.writer(f)
# ----> 4           writer.writerows(write_list)
#       5
#       6 from google.colab import files
#
# NameError: name 'write_list' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
